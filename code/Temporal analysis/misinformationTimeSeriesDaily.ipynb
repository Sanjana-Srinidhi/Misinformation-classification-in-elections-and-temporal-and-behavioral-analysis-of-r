# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import re
import pandas as pd
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
import matplotlib.patches as mpatches

# %%
df = pd.read_csv('/content/drive/MyDrive/DA/data/Datasets/combined_dataset.csv')
df.head()
# Out:
#                                                title  \
# 0  China's ruling Communist Party expels former G...
# 1  Trump: U.S. will win appeal of judge's travel ...
# 2  A DEFENSIVE JOHN KERRY Asks That Israel Move I...
# 3       EU calls report on May-Juncker talks a smear
# 4  HIV POSITIVE, CRACK SMOKING, Liberal Actor Cha...
#
#                                                 text          subject  \
# 0  BEIJING (Reuters) - China s ruling Communist P...        worldnews
# 1  WASHINGTON/PALM BEACH, Fla (Reuters) - U.S. Pr...     politicsNews
# 2  John Kerry gave a long-winded speech today cla...  Government News
# 3  BRUSSELS (Reuters) - The European Commission s...        worldnews
# 4  Less than one year ago, Charlie Sheen s ex-wif...         politics
#
#                   date  label
# 0  September 22, 2017       1
# 1    February 3, 2017       1
# 2         Dec 28, 2016      0
# 3    October 23, 2017       1
# 4         Dec 29, 2016      0

# %%
df['date'] = pd.to_datetime(df['date'], errors = 'coerce')
df.dtypes
# Out:
# title              object
# text               object
# subject            object
# date       datetime64[ns]
# label               int64
# dtype: object

# %%
misinformation_df = df.loc[df['label'] == 0]
misinformation_df = misinformation_df[['date', 'text', 'label']]
misinformation_df.head()
# Out:
#          date                                               text  label
# 2  2016-12-28  John Kerry gave a long-winded speech today cla...      0
# 4  2016-12-29  Less than one year ago, Charlie Sheen s ex-wif...      0
# 6  2016-12-27  Donald Trump is still using his Twitter accoun...      0
# 7  2016-07-05  The GOP has been impatiently waiting for the m...      0
# 13 2016-01-24  We hear so much talk from the Left about worki...      0

# %%
def timec(i):
  i = str(i)
  i = i[0:10]
  return i
misinformation_df['date'] = misinformation_df['date'].apply(timec)
misinformation_df.head()
# Out:
#           date                                               text  label
# 2   2016-12-28  John Kerry gave a long-winded speech today cla...      0
# 4   2016-12-29  Less than one year ago, Charlie Sheen s ex-wif...      0
# 6   2016-12-27  Donald Trump is still using his Twitter accoun...      0
# 7   2016-07-05  The GOP has been impatiently waiting for the m...      0
# 13  2016-01-24  We hear so much talk from the Left about worki...      0

# %%
list_t = misinformation_df['date'].values.tolist()
misinformation_dict = dict()
for i in range(len(list_t)):
  if list_t[i] not in misinformation_dict:
    misinformation_dict[list_t[i]] = 0
  misinformation_dict[list_t[i]] = misinformation_dict[list_t[i]] + 1
print(misinformation_dict)
list_t = list(misinformation_dict.keys())
count = list(misinformation_dict.values())
time = pd.DataFrame({'Time': list_t, 'Frequency': count})
time = time.dropna()
time.reset_index(inplace = True)
time = time.sort_values('Time')
time.head()
# Out:
017-04-08': 23, '2016-08-31': 31, '2016-01-21': 35, '2016-01-26': 36, '2017-03-23': 37, '2016-10-26': 35, '2016-10-22': 32, '2017-11-25': 15, '2016-07-20': 27, '2017-01-11': 36, '2016-07-13': 25, '2017-04-23': 22, '2017-06-06': 35, '2017-02-07': 24, '2016-04-18': 29, '2016-10-18': 32, '2017-05-08': 24, '2017-10-11': 18, '2016-04-12': 35, '2016-02-15': 33, '2017-02-18': 25, '2017-01-29': 32, '2017-03-17': 43, '2016-03-08': 37, '2016-10-31': 38, '2017-03-27': 26, '2016-09-19': 35, '2016-05-01': 37, '2017-01-18': 26, '2016-10-20': 37, '2017-02-28': 40, '2015-11-15': 6, '2017-01-07': 32, '2016-02-07': 41, '2015-10-23': 13, '2017-06-14': 31, '2016-06-21': 20, '2015-12-28': 10, '2016-02-10': 42, '2017-05-11': 36, '2016-08-05': 30, '2016-12-02': 25, '2017-06-01': 21, '2016-11-29': 30, '2016-11-06': 37, '2016-03-15': 42, '2018-02-16': 8, '2017-01-13': 36, '2017-04-01': 23, '2015-11-17': 8, '2017-09-28': 27, '2016-09-03': 40, '2015-09-24': 10, '2017-03-24': 40, '2016-10-13': 34, '2016-06-26': 29, '2016-10-29': 25, '2016-11-03': 33, '2016-10-25': 34, '2017-07-13': 25, '2017-12-19': 11, '2016-01-20': 44, '2017-12-11': 16, '2017-02-26': 30, '2017-06-09': 24, '2016-10-16': 23, '2017-10-22': 14, '2017-12-12': 17, '2017-08-03': 21, '2017-05-24': 14, '2017-03-08': 35, '2017-03-21': 32, '2017-07-25': 20, '2016-02-19': 34, '2016-07-11': 25, '2016-10-08': 35, '2017-07-31': 23, '2015-07-17': 14, '2016-01-12': 38, '2015-06-02': 7, ...
#       index        Time  Frequency
# 409     409  2015-03-31          8
# 1004   1004  2015-04-01          2
# 943     943  2015-04-02          1
# 640     640  2015-04-04          5
# 874     874  2015-04-05         13

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x = time['Time'], y = time['Frequency'], name = 'Misinformation news', line = dict(color = 'blue', width = 2)))
fig.update_layout(xaxis_title = 'Month-Year', yaxis_title = 'Frequency')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9834f119-9dcb-4947-afc1-76aa15e9805b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9834f119-9dcb-4947-afc1-76aa15e9805b")) {                    Plotly.newPlot(                        "9834f119-9dcb-4947-afc1-76aa15e9805b",                        [{"line":{"color":"blue","width":2},"name":"Misinformation news","x":["2015-03-31","2015-04-01","2015-04-02","2015-04-04","2015-04-05","2015-04-06","2015-04-07","2015-04-08","2015-04-09","2015-04-10","2015-04-11","2015-04-12","2015-04-13","2015-04-14","2015-04-15","2015-04-16","2015-04-17","2015-04-18","2015-04-19","2015-04-20","2015-04-21","2015-04-22","2015-04-23","2015-04-24","2015-04-25","2015-04-26","2015-04-27","2015-04-28","2015-04-29","2015-04-30","2015-05-01","2015-05-02","2015-05-04","2015-05-05","2015-05-06","2015-05-07","2015-05-08","2015-05-09","2015-05-10","2015-05-11","2015-05-12","2015-05-13","2015-05-14","2015-05-15","2015-05-16","2015-05-17","2015-05-18","2015-05-19","2015-05-20","2015-05-21","2015-05-22","2015-05-23","2015-05-24","2015-05-25","2015-05-26","2015-05-27","2015-05-28","2015-05-29","2015-05-30","2015-05-31","2015-06-01","2015-06-02","2015-06-03","2015-06-04","2015-06-05","2015-06-07","2015-06-08","2015-06-09","2015-06-10","2015-06-11","2015-06-12","2015-06-13","2015-06-14","2015-06-15","2015-06-16","2015-06-17","2015-06-18","2015-06-19","2015-06-20","2015-06-21","2015-06-22","2015-06-23","2015-06-24","2015-06-25","2015-06-26","2015-06-27","2015-06-28","2015-06-29","2015-06-30","2015-07-01","2015-07-02","2015-07-03","2015-07-04","2015-07-05","2015-07-06","2015-07-07","2015-07-08","2015-07-09","2015-07-10","2015-07-11","2015-07-12","2015-07-13","2015-07-14","2015-07-15","2015-07-16","2015-07-17","2015-07-18","2015-07-19","2015-07-20","2015-07-21","2015-07-22","2015-07-23","2015-07-24","2015-07-25","2015-07-26","2015-07-27","2015-07-28","2015-07-29","2015-07-30","2015-07-31","2015-08-01","2015-08-02","2015-08-03","2015-08-04","2015-08-05","2015-08-06","2015-08-07","2015-08-08","2015-08-09","2015-08-10","2015-08-11","2015-08-12","2015-08-13","2015-08-14","2015-08-15","2015-08-16","2015-08-17","2015-08-18","2015-08-19","2015-08-20","2015-08-21","2015-08-22","2015-08-23","2015-08-24","2015-08-25","2015-08-26","2015-08-27","2015-08-28","2015-08-29","2015-08-30","2015-08-31","2015-09-01","2015-09-02","2015-09-03","2015-09-04","2015-09-05","2015-09-06","2015-09-07","2015-09-08","2015-09-09","2015-09-10","2015-09-11","2015-09-12","2015-09-13","2015-09-14","2015-09-15","2015-09-16","2015-09-17","2015-09-18","2015-09-19","2015-09-20","2015-09-21","2015-09-22","2015-09-23","2015-09-24","2015-09-25","2015-09-26","2015-09-27","2015-09-28","2015-09-29","2015-09-30","2015-10-01","2015-10-02","2015-10-03","2015-10-04","2015-10-05","2015-10-06","2015-10-07","2015-10-08","2015-10-09","2015-10-10","2015-10-11","2015-10-12","2015-10-13","2015-10-14","2015-10-15","2015-10-16","2015-10-17","2015-10-18","2015-10-19","2015-10-20","2015-10-21","2015-10-22","2015-10-23","2015-10-24","2015-10-25","2015-10-26","2015-10-27","2015-10-28","2015-10-29","2015-10-30","2015-10-31","2015-11-01","2015-11-02","2015-11-03","2015-11-04","2015-11-05","2015-11-06","2015-11-07","2015-11-08","2015-11-09","2015-11-10","2015-11-11","2015-11-12","2015-11-13","2015-11-14","2015-11-15","2015-11-16","2015-11-17","2015-11-18","2015-11-19","2015-11-20","2015-11-21","2015-11-22","2015-11-23","2015-11-24","2015-11-25","2015-11-26","2015-11-27","2015-11-28","2015-11-29","2015-11-30","2015-12-01","2015-12-02","2015-12-03","2015-12-04","2015-12-05","2015-12-06","2015-12-07","2015-12-08","2015-12-09","2015-12-10","2015-12-11","2015-12-12","2015-12-13","2015-12-14","2015-12-15","2015-12-16","2015-12-17","2015-12-18","201 ...

# %%
time.to_csv('/content/drive/MyDrive/DA/data/Time Series data/misinformation_timeseries_daily.csv', index = False)
