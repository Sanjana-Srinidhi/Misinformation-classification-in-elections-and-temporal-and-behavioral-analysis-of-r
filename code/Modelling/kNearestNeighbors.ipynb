# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df_train = pd.read_csv('/content/drive/MyDrive/DA/data/Datasets/train.csv')
df_train.head()
# Out:
#                                                title  \
# 0  arizona gop poised ban social justice classes ...
# 1  trump tells supporters he’ll enact law actuall...
# 2         us senate vote montenegros nato membership
# 3  paul craig roberts ‘by cooperating washington ...
# 4  president trump tweets perfect new years messa...
#
#                                                 text       subject  \
# 0  another day another assault first amendment fr...          News
# 1  one would think donald trump would learned les...          News
# 2  washington reuters us senate vote next week ra...  politicsNews
# 3  paul crag robertsa month ago wrote column hesi...       US_News
# 4  comes close like acknowledge gratitude preside...      politics
#
#                date  label  year
# 0  January 14, 2017      0  2017
# 1     June 22, 2017      0  2017
# 2   March 23, 2017       1  2017
# 3  October 26, 2016      0  2016
# 4      Dec 31, 2017      0  2017

# %%
df_test = pd.read_csv('/content/drive/MyDrive/DA/data/Datasets/test.csv')
df_test.head()
# Out:
#                                                title  \
# 0   WATCH: Bernie Sanders Makes MAJOR Announcemen...
# 1  Trump renews threat to scrap NAFTA going into ...
# 2  Minor train disruption rattles Singapore's rep...
# 3  Factbox: Who are Britain First, whose leader's...
# 4   The Los Angeles Times Endorses Hillary Clinto...
#
#                                                 text       subject  \
# 0  The mood at Democratic presidential hopeful Be...          News
# 1  WASHINGTON (Reuters) - U.S. President Donald T...  politicsNews
# 2  SINGAPORE (Reuters) - Singapore is grappling w...     worldnews
# 3  LONDON (Reuters) - U.S. President Donald Trump...     worldnews
# 4  As Politico reports an almost neck-and-neck ra...          News
#
#                  date  label
# 0      March 27, 2016      0
# 1    August 27, 2017       1
# 2   November 9, 2017       1
# 3  November 29, 2017       1
# 4        May 30, 2016      0

# %%
df_train.isna().sum()
# Out:
# title       0
# text       52
# subject     0
# date        0
# label       0
# year        0
# dtype: int64

# %%
df_train = df_train.dropna()
df_train.isna().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# year       0
# dtype: int64

# %%
x_train = df_train['text']
y_train = df_train['label']
x_test = df_test['text']
y_test = df_test['label']

# %%
knn = Pipeline([('vect', CountVectorizer()), ('tfidf', TfidfTransformer()), ('clf', KNeighborsClassifier(n_neighbors = 5)),])
knn.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('clf', KNeighborsClassifier())])

# %%
y_pred = knn.predict(x_test)
score = accuracy_score(y_test, y_pred)
print(f'Accuracy: {round(score * 100, 2)}%')
# Out:
# Accuracy: 64.39%

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.34      0.50      7067
#            1       0.57      0.98      0.72      6403
#
#     accuracy                           0.64     13470
#    macro avg       0.76      0.66      0.61     13470
# weighted avg       0.77      0.64      0.61     13470

# %%
cm = confusion_matrix(y_test, y_pred)
cm_matrix = pd.DataFrame(data = cm, columns = ['Actual Positive:0', 'Actual Negative:1'], index = ['Predict Positive:0', 'Predict Negative:1'])
sns.heatmap(cm_matrix, annot = True, fmt = 'd', cmap = 'YlGnBu')
